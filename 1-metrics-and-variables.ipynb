# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# %%
url='https://drive.google.com/file/d/1zLKWeJ_OZjxuKlP561-GopniC0_Pt_X6/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#          age  number_of_children         income
# 0  42.772420                   0   34396.537188
# 1  29.561090                   0  183350.052521
# 2  54.380735                   0   53689.856555
# 3  42.551689                   0  109080.913926
# 4  38.713080                   0  153612.343419

# %%
df['number_of_children'].value_counts()
# Out:
# number_of_children
# 0    658
# 1    226
# 2     94
# 3     20
# 5      1
# 4      1
# Name: count, dtype: int64

# %%
df['number_of_children'].value_counts(normalize=True)
# Out:
# number_of_children
# 0    0.658
# 1    0.226
# 2    0.094
# 3    0.020
# 5    0.001
# 4    0.001
# Name: proportion, dtype: float64

# %%
df['number_of_children'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(df['number_of_children'])
# Out:
# <Axes: xlabel='number_of_children', ylabel='Count'>

# %%
sns.histplot(df['number_of_children'],stat='probability')
# Out:
# <Axes: xlabel='number_of_children', ylabel='Probability'>

# %%
df['age'].value_counts()
# Out:
# age
# 42.772420    1
# 29.524914    1
# 23.576408    1
# 40.563444    1
# 41.557756    1
#             ..
# 63.789406    1
# 27.576455    1
# 28.502233    1
# 30.699148    1
# 46.662848    1
# Name: count, Length: 1000, dtype: int64

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age_bins'] = pd.cut(df['age'],10)

# %%
df.groupby('age_bins')['age'].count()
# Out:
# age_bins
# (17.402, 22.107]     49
# (22.107, 26.766]    124
# (26.766, 31.425]    140
# (31.425, 36.084]    134
# (36.084, 40.743]    131
# (40.743, 45.401]    141
# (45.401, 50.06]     101
# (50.06, 54.719]     121
# (54.719, 59.378]     50
# (59.378, 64.037]      9
# Name: age, dtype: int64

# %% [markdown]
# # Mean

# %%
df['number_of_children'].mean()
# Out:
# 0.483

# %%
df['age'].mean()
# Out:
# 38.31925590719966

# %%
df.describe()
# Out:
#                age  number_of_children         income
# count  1000.000000         1000.000000    1000.000000
# mean     38.319256            0.483000  129415.746378
# std      10.644724            0.768311   71251.620971
# min      17.448452            0.000000   21943.855414
# 25%      29.374744            0.000000   79594.040400
# 50%      37.710596            0.000000  114586.570939
# 75%      46.778096            1.000000  162888.891081
# max      64.036559            5.000000  678006.351857

# %% [markdown]
# # Median

# %%
pd.Series([30,30,40,60,50]).mean()
# Out:
# 42.0

# %%
pd.Series([30,30,40,60,50,999999999]).mean()
# Out:
# 166666701.5

# %%
pd.Series([30,30,40,60,50,999999999]).hist()
# Out:
# <Axes: >

# %%
salary = pd.Series([30,30,40,60,50]).sort_values()

# %%
salary
# Out:
# 0    30
# 1    30
# 2    40
# 4    50
# 3    60
# dtype: int64

# %%
salary.median()
# Out:
# 40.0

# %%
salary = pd.Series([30,30,40,60,50,9999999999])

# %%
salary.median()
# Out:
# 45.0

# %%
df['income'].median()
# Out:
# 114586.57093898312

# %%
(df['income'] < df['income'].median()).mean()
# Out:
# 0.5

# %% [markdown]
# # Mode

# %%
df.head()
# Out:
#          age  number_of_children         income          age_bins
# 0  42.772420                   0   34396.537188  (40.743, 45.401]
# 1  29.561090                   0  183350.052521  (26.766, 31.425]
# 2  54.380735                   0   53689.856555   (50.06, 54.719]
# 3  42.551689                   0  109080.913926  (40.743, 45.401]
# 4  38.713080                   0  153612.343419  (36.084, 40.743]

# %%
df['number_of_children'].value_counts()
# Out:
# number_of_children
# 0    658
# 1    226
# 2     94
# 3     20
# 5      1
# 4      1
# Name: count, dtype: int64

# %%
df['number_of_children'].mode()
# Out:
# 0    0
# Name: number_of_children, dtype: int64

# %% [markdown]
# # Quantile

# %%
df['income'].agg(['mean','median'])
# Out:
# mean      129415.746378
# median    114586.570939
# Name: income, dtype: float64

# %%
df['income'].hist()
# Out:
# <Axes: >

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
df['income'] < 114586.570939
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: income, Length: 1000, dtype: bool

# %%
(df['income'] < 114586.570939).mean()
# Out:
# 0.5

# %%
(df['income'] < 100000).mean()
# Out:
# 0.397

# %%
(df['income'] < df['income'].quantile(0.4)).mean()
# Out:
# 0.4

# %%
df['income'].quantile(0.1)
# Out:
# 58377.17440989983

# %%
df['income'].quantile(0.3)
# Out:
# 86626.68913102671

# %%
df['income'].quantile(0.25)
# Out:
# 79594.0403996465

# %%
df['income'].quantile(0.5)
# Out:
# 114586.57093898312

# %%
df['income'].quantile(0.75)
# Out:
# 162888.8910808624

# %% [markdown]
# # Boxplot

# %%
df.head()
# Out:
#          age  number_of_children         income          age_bins
# 0  42.772420                   0   34396.537188  (40.743, 45.401]
# 1  29.561090                   0  183350.052521  (26.766, 31.425]
# 2  54.380735                   0   53689.856555   (50.06, 54.719]
# 3  42.551689                   0  109080.913926  (40.743, 45.401]
# 4  38.713080                   0  153612.343419  (36.084, 40.743]

# %%
df['age'].rank(pct=True).head()
# Out:
# 0    0.639
# 1    0.257
# 2    0.936
# 3    0.634
# 4    0.521
# Name: age, dtype: float64

# %%
df['age_pct'] = df['age'].rank(pct=True)

# %%
df.head()
# Out:
#          age  number_of_children         income          age_bins  age_pct
# 0  42.772420                   0   34396.537188  (40.743, 45.401]    0.639
# 1  29.561090                   0  183350.052521  (26.766, 31.425]    0.257
# 2  54.380735                   0   53689.856555   (50.06, 54.719]    0.936
# 3  42.551689                   0  109080.913926  (40.743, 45.401]    0.634
# 4  38.713080                   0  153612.343419  (36.084, 40.743]    0.521

# %%
(df['age'] < 42.772420).mean()
# Out:
# 0.638

# %%
df[['age']].boxplot()
# Out:
# <Axes: >

# %%
df[['income']].boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(df['income'])
# Out:
# <Axes: >

# %% [markdown]
# # std, mad

# %%
df['income'].hist()
# Out:
# <Axes: >

# %%
df['income'].describe()
# Out:
# count      1000.000000
# mean     129415.746378
# std       71251.620971
# min       21943.855414
# 25%       79594.040400
# 50%      114586.570939
# 75%      162888.891081
# max      678006.351857
# Name: income, dtype: float64

# %%
(df['income'] - df['income'].mean()).hist()
# Out:
# <Axes: >

# %%
(df['income'] - df['income'].mean()).mean()
# Out:
# 5.1222741603851315e-12

# %%
np.mean([-2,2])
# Out:
# 0.0

# %%
np.mean(np.abs([-2,2]))
# Out:
# 2.0

# %%
(df['income'] - df['income'].mean()).abs().mean()
# Out:
# 51910.29730549474

# %%
df['income'].describe()
# Out:
# count      1000.000000
# mean     129415.746378
# std       71251.620971
# min       21943.855414
# 25%       79594.040400
# 50%      114586.570939
# 75%      162888.891081
# max      678006.351857
# Name: income, dtype: float64

# %%
((df['income'] - df['income'].mean())**2).mean()
# Out:
# 5071716697.45695

# %%
np.sqrt(((df['income'] - df['income'].mean())**2).mean())
# Out:
# 71215.98624927517

# %%
np.sqrt(((df['income'] - df['income'].mean())**2).sum() / (len(df)-1))
# Out:
# 71251.62097066913

# %% [markdown]
# mad > std

# %%
(df['income'] - df['income'].mean()).abs().mean()
# Out:
# 51910.29730549474

# %% [markdown]
# # corr only linear

# %%
df[['age','income']].corr()
# Out:
#              age    income
# age     1.000000 -0.048164
# income -0.048164  1.000000

# %%
df.groupby('age_bins')['income'].agg(['count','mean','median'])
# Out:
#                   count           mean         median
# age_bins
# (17.402, 22.107]     49  104319.382165   88163.526875
# (22.107, 26.766]    124  133775.791324  125960.906191
# (26.766, 31.425]    140  130575.738767  114947.477353
# (31.425, 36.084]    134  135654.848704  118368.874351
# (36.084, 40.743]    131  134457.081592  128647.922872
# (40.743, 45.401]    141  139697.676942  123441.920529
# (45.401, 50.06]     101  142814.622910  122199.047306
# (50.06, 54.719]     121  112563.104588   95443.103632
# (54.719, 59.378]     50  104040.538214   91602.734609
# (59.378, 64.037]      9   77761.750813   78167.926251

# %%
df.groupby('age_bins')['income'].median().plot(rot=50,ylim=0)
# Out:
# <Axes: xlabel='age_bins'>

# %%
df.plot(x='age',y='income',kind='scatter')
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
df.groupby('number_of_children')['income'].agg(['count','mean','median'])
# Out:
#                     count           mean         median
# number_of_children
# 0                     658  126715.541703  110189.980527
# 1                     226  132978.451169  124840.813434
# 2                      94  130142.466654  113863.126537
# 3                      20  175810.993223  112983.579288
# 4                       1  134556.798410  134556.798410
# 5                       1   99621.445364   99621.445364

# %%
df.groupby('number_of_children')['income'].median().plot(ylim=80000)
# Out:
# <Axes: xlabel='number_of_children'>

# %%
df[['number_of_children','income']].corr()
# Out:
#                     number_of_children    income
# number_of_children            1.000000  0.065774
# income                        0.065774  1.000000
